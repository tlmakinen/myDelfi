# %%
cd /Users/lucas/repositories/myDelfi
# Out:
# /Users/lucas/repositories/myDelfi

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from plotting import *
from ndes import *
from mdn import *
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
# import data
theta_ = (np.load('./borg-imnn/regression/results/results_wiener/theta_reg_wiener.npy').astype(np.float32))
summaries_ = np.load('./borg-imnn/regression/results/results_wiener/x_reg_wiener.npy').astype(np.float32)

#t2 = (np.load('./borg-imnn/regression/regression_theta2_amp.npy').astype(np.float32))
#s2 = np.load('./borg-imnn/regression/regression_x2_amp.npy').astype(np.float32)

max_om = 0.9

mask = theta_[:, 0] < max_om

theta_ = theta_[mask]
summaries_ = summaries_[mask]

#summaries_ = summaries_.reshape(summaries_.shape[0], 4)

weights = np.ones((summaries_.shape[0], 1)).astype(np.float32)


eps = 0.05

# bijector theta -> phi
theta_min = [0.1 - eps, 0.4 - eps]
theta_max = [max_om + eps, 1.6 + eps]
bijector = tfb.Blockwise([tfb.Chain([tfb.Invert(tfb.NormalCDF()), tfb.Scale(np.float32(1./(theta_max[_] - theta_min[_]))), tfb.Shift(-theta_min[_])]) for _ in range(len(theta_min))])

# phi
phi_ = bijector(theta_).numpy()

# %%
theta_[:, 0].min()
# Out:
# 0.10016517

# %%
theta_.shape, summaries_.shape, phi_.shape
# Out:
# ((2000, 2), (2000, 2), (2000, 2))

# %%
plt.scatter(phi_[:, 0], (summaries_[:, 0]), s=3)
#plt.axvline(0.27, color='k')
plt.show()

# %%
plt.scatter(phi_[:,1], (summaries_[:,1]), s=0.1)
plt.show()

# %%
theta = tf.convert_to_tensor(theta_, dtype=tf.float32)
phi   = tf.convert_to_tensor(phi_, dtype=tf.float32)
weights = tf.convert_to_tensor(weights, dtype=tf.float32)
summaries = tf.convert_to_tensor(summaries_, dtype=tf.float32)

# %%
# Amortized posterior
filename = './borg-imnn/regression/results/results_wiener/amortized_post'
AmortizedPosterior = MixtureDensityNetwork2(n_components=3, 
                            n_conditionals=2, 
                            n_dimensions=2, 
                            optimizer=tf.keras.optimizers.Adam(lr=1e-3),
                            n_hidden=[64, 64],
                            activation=[tf.tanh, tf.tanh])

# %%
AmortizedPosterior.optimizer = tf.keras.optimizers.Adam(lr=1e-4)
historyAP = AmortizedPosterior.fit(training_conditionals=summaries, training_variables=phi, training_weights=weights, 
                        epochs=3000, batch_size=50, patience=500, save=True, filename=filename)
# Out:
#  17%|█▋        | 500/3000 [01:15<06:18,  6.60it/s, training loss=1.2, validation_loss=1.21]

# %%
# reload best model
AmortizedPosterior = MixtureDensityNetwork2(n_components=6, 
                            n_conditionals=4, 
                            n_dimensions=2, 
                            optimizer=tf.keras.optimizers.Adam(lr=1e-4),
                            n_hidden=[50, 100],
                            activation=[tf.tanh, tf.tanh],
                            restore=True,
                            restore_filename=filename)

# %%
summaries_obs = np.load('./borg-imnn/regression/results/results_wiener/reg_estimates_wiener.npy') #np.array([0.3215735 , 0.75502646]).astype(np.float32) #  [0.30336806, 0.7549215 ]

# %%
# plot over a grid
omegaM = np.linspace(0.11, 0.9, 70)
sigma8 = np.linspace(0.41, 1.6, 110)
OM, S8 = np.meshgrid(omegaM, sigma8)
theta_grid = np.concatenate([OM[...,np.newaxis], S8[...,np.newaxis]], axis=-1)
phi_grid = bijector(theta_grid)

cond_shape = theta_grid.shape[:-1] + (2,)

log_prob = tf.squeeze(AmortizedPosterior.log_prob(phi_grid, conditional=summaries_obs*np.ones(cond_shape).astype(np.float32))).numpy()
#log_prob = SamplingDistribution.log_prob(summaries_obs*np.ones(phi_grid.shape).astype(np.float32), conditional=theta_grid).numpy()
log_prob = log_prob - max(log_prob.flatten())

# %%
plt.contourf(omegaM, sigma8, np.exp(log_prob))
plt.show()

# %%
np.std(theta[:,0])
# Out:
# 0.23223354

# %%
Posterior = AmortizedPosterior.distribution(summaries_obs[np.newaxis, :].astype(np.float32))

posterior_samples = bijector.inverse(Posterior.sample(100000)).numpy()
cut = np.all(~np.isinf(posterior_samples), axis=-1)
posterior_samples = posterior_samples[cut,:]


# cut = posterior_samples[:, 0] < 0.8
# posterior_samples = posterior_samples[cut, :]

# cut = posterior_samples[:, 0] > 0.1
# posterior_samples = posterior_samples[cut, :]

# %%
plt.hist(posterior_samples[:, 0])
# Out:
# (array([3.0740e+03, 2.8731e+04, 4.1785e+04, 2.0014e+04, 4.7090e+03,
#         1.0280e+03, 4.0200e+02, 1.7700e+02, 6.6000e+01, 1.4000e+01]),
#  array([0.10024131, 0.17792846, 0.25561562, 0.33330277, 0.4109899 ,
#         0.48867705, 0.5663642 , 0.6440514 , 0.7217385 , 0.79942566,
#         0.8771128 ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
# Posterior = SamplingDistribution.distribution(conditional=summaries_obs[:,np.newaxis].astype(np.float32))

# posterior_samples = (Posterior.sample(10000)).numpy()
# cut = np.all(~np.isinf(posterior_samples), axis=-1)
# posterior_samples = posterior_samples[cut,:]

# %%
np.save('./borg-imnn/regression/results/results_wiener/posterior_samples', posterior_samples)

# %%
from chainconsumer import ChainConsumer

_psts = posterior_samples.copy()
#_psts[:, 0] = 0.3*(posterior_samples[:, 0]**2 / posterior_samples[:, 1]**2)

cs = ChainConsumer()
cs.add_chain(_psts, parameters=['omegaM', 'sigma8'], name='DELFI + IMNN') #, color=corner_colors[0])
#cs.add_covariance(θ_target, -Finv_analytic, parameters=params, name="Analytic Fisher", color=corner_colors[2])
cs.configure(linestyles=["-", "-", "-"], linewidths=[1.0, 1.0, 1.0], usetex=False,
        shade=[True, True, False], shade_alpha=[0.7, 0.6, 0.], tick_font_size=8, sigma2d=True)
cs.plotter.plot((7,7))
plt.show()

# %% [markdown]
# # now set up PIT coverage tests
#
# for every pair (theta*, data*) in the training set, for each of the marginals compute P(theta < theta* | data*), and plot the distribution of those cumulative probabilities

# %%
from tqdm import tqdm

# %%
omegam_cdfs = []
sigma8_cdfs = []

for i in tqdm(range(5000)):
  theta_i = theta_[i]
  summary_i = summaries_[i]
  # could add tfp mixture model here for more than one MDN
  # p(theta | x)
  dist = AmortizedPosterior.distribution(summary_i[np.newaxis, :].astype(np.float32))
  
  samps = bijector.inverse(dist.sample(100000)).numpy()
  cut = np.all(~np.isinf(samps), axis=-1)
  samps = samps[cut,:]
  norm = samps.shape[0]


  #for each marginal
  omegam_cdfs.append(np.sum(samps[:, 0] <= theta_i[0]) / norm) 
  sigma8_cdfs.append(np.sum(samps[:, 1] <= theta_i[1]) / norm)

  #plt.hist(samps[:, 1])
  #plt.axvline(theta_i[:, 1])
# Out:
#  16%|█▌        | 794/5000 [01:39<08:47,  7.98it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-596-ee0fefa045ec> in <module>
#       9   dist = AmortizedPosterior.distribution(summary_i[np.newaxis, :].astype(np.float32))
#      10
# ---> 11   samps = bijector.inverse(dist.sample(100000)).numpy()
#      12   cut = np.all(~np.isinf(samps), axis=-1)
#      13   samps = samps[cut,:]
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/bijector.py in inverse(self, y, name, **kwargs)
#    1429       NotImplementedError: if `_inverse` is not implemented.
#    1430     """
# -> 1431     return self._call_inverse(y, name, **kwargs)
#    1432
#    1433   def _call_inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/bijector.py in _call_inverse(self, y, name, **kwargs)
#    1409       if not self._is_injective:  # No caching for non-injective
#    1410         return self._inverse(y, **kwargs)
# -> 1411       return self._cache.inverse(y, **kwargs)
#    1412
#    1413   def inverse(self, y, name='inverse', **kwargs):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py in inverse(self, y, **kwargs)
#     345       The output of the bijector's `_inverse` method, or a cached result.
#     346     """
# --> 347     return self._lookup(y, self._inverse_name, self._forward_name, **kwargs)
#     348
#     349   def forward_attributes(self, x, **kwargs):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py in _lookup(self, input, forward_name, inverse_name, **kwargs)
#     491       output = nest.map_structure(
#     492           _containerize,
# --> 493           self._invoke(input, forward_name, kwargs, attrs))
#     494       output_ref = WeakStructRef(
#     495           output,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py in _invoke(self, input, fn_name, kwargs, attributes)
#     530   def _invoke(self, input, fn_name, kwargs, attributes):  # pylint: disable=unused-argument
#     531     """Invokes the wrapped function. Override to customize behavior."""
# --> 532     return getattr(self.bijector, fn_name)(input, **kwargs)
#     533
#     534   def clear(self):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/blockwise.py in _inverse(self, y, **kwargs)
#     193
#     194   def _inverse(self, y, **kwargs):
# --> 195     x = super(_Blockwise, self)._inverse(y, **kwargs)
#     196     if not self._maybe_changes_size:
#     197       tensorshape_util.set_shape(x, y.shape)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/composition.py in _inverse(self, y, **kwargs)
#     612           'Invert is not implemented for compositions of '
#     613           'non-injective bijectors.')
# --> 614     return self._call_walk_inverse(
#     615         lambda b, y, **kwargs: b.inverse(y, **kwargs),
#     616         y, **kwargs)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/composition.py in _call_walk_inverse(self, step_fn, *args, **kwargs)
#     350
#     351     if len(args) == 1:
# --> 352       return self._walk_inverse(step_fn, *args, **kwargs)
#     353
#     354     # Convert a tuple of structures to a structure of tuples. This
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/blockwise.py in _walk_inverse(self, step_fn, x, **kwargs)
#     233
#     234   def _walk_inverse(self, step_fn, x, **kwargs):
# --> 235     return self._chain._walk_inverse(  # pylint: disable=protected-access
#     236         step_fn, x, **{self._b_joint.name: kwargs})
#     237
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/chain.py in _walk_inverse(self, step_fn, y, **kwargs)
#     146     """Applies `transform_fn` to `y` sequentially over nested bijectors."""
#     147     for bij in self._bijectors:
# --> 148       y = step_fn(bij, y, **kwargs.get(bij.name, {}))
#     149     return y  # Now `x`
#     150
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/composition.py in <lambda>(b, y, **kwargs)
#     613           'non-injective bijectors.')
#     614     return self._call_walk_inverse(
# --> 615         lambda b, y, **kwargs: b.inverse(y, **kwargs),
#     616         y, **kwargs)
#     617
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/bijector.py in inverse(self, y, name, **kwargs)
#    1429       NotImplementedError: if `_inverse` is not implemented.
#    1430     """
# -> 1431     return self._call_inverse(y, name, **kwargs)
#    1432
#    1433   def _call_inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/bijector.py in _call_inverse(self, y, name, **kwargs)
#    1409       if not self._is_injective:  # No caching for non-injective
#    1410         return self._inverse(y, **kwargs)
# -> 1411       return self._cache.inverse(y, **kwargs)
#    1412
#    1413   def inverse(self, y, name='inverse', **kwargs):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py in inverse(self, y, **kwargs)
#     345       The output of the bijector's `_inverse` method, or a cached result.
#     346     """
# --> 347     return self._lookup(y, self._inverse_name, self._forward_name, **kwargs)
#     348
#     349   def forward_attributes(self, x, **kwargs):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py in _lookup(self, input, forward_name, inverse_name, **kwargs)
#     482     if input is None:
#     483       raise ValueError('Input must not be None.')
# --> 484     input_ref, output_ref, attrs, _ = self._get_or_create_edge(
#     485         input, forward_name, kwargs)
#     486     if output_ref:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py in _get_or_create_edge(self, input, forward_name, kwargs)
#     515   def _get_or_create_edge(self, input, forward_name, kwargs):
#     516     """Gets the _Edge associated with an input."""
# --> 517     test_ref = WeakStructRef(
#     518         input,
#     519         subkey=(self.bijector, self.bijector_class, forward_name, kwargs),
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py in __init__(self, struct, subkey, callback)
#     135     # we assume that their hashes are stable and unchanging.
#     136     # Compute the hash and store it with the object.
# --> 137     self._hash = hash(hashable_structure((self._struct, self._subkey)))
#     138     self._callback = callback
#     139     self._alive = True
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/bijector.py in __hash__(self)
#     826
#     827   def __hash__(self):
# --> 828     return hash(cache_util.hashable_structure((
#     829         type(self), self._get_parameterization())))
#     830
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py in hashable_structure(struct)
#      47       return ObjectIdentityWrapper(obj)
#      48   # Flatten structs into a tuple of tuples to make mutable containers hashable.
# ---> 49   return tuple((k, make_hashable(v))
#      50                for k, v in nest.flatten_with_tuple_paths(struct))
#      51
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py in <genexpr>(.0)
#      47       return ObjectIdentityWrapper(obj)
#      48   # Flatten structs into a tuple of tuples to make mutable containers hashable.
# ---> 49   return tuple((k, make_hashable(v))
#      50                for k, v in nest.flatten_with_tuple_paths(struct))
#      51
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py in make_hashable(obj)
#      42       return ObjectIdentityWrapper(obj)
#      43     try:
# ---> 44       hash(obj)
#      45       return obj
#      46     except TypeError:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/bijector.py in __hash__(self)
#     826
#     827   def __hash__(self):
# --> 828     return hash(cache_util.hashable_structure((
#     829         type(self), self._get_parameterization())))
#     830
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/bijectors/bijector.py in __hash__(self)
#     826
#     827   def __hash__(self):
# --> 828     return hash(cache_util.hashable_structure((
#     829         type(self), self._get_parameterization())))
#     830
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/cache_util.py in hashable_structure(struct)
#      48   # Flatten structs into a tuple of tuples to make mutable containers hashable.
#      49   return tuple((k, make_hashable(v))
# ---> 50                for k, v in nest.flatten_with_tuple_paths(struct))
#      51
#      52
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in flatten_with_tuple_paths(structure, expand_composites)
#    1642   return list(zip(yield_flat_paths(structure,
#    1643                                    expand_composites=expand_composites),
# -> 1644                   flatten(structure, expand_composites=expand_composites)))
#    1645
#    1646
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in flatten(structure, expand_composites)
#     415     return [None]
#     416   expand_composites = bool(expand_composites)
# --> 417   return _pywrap_utils.Flatten(structure, expand_composites)
#     418
#     419
#
# KeyboardInterrupt:

# %%
plt.hist(omegam_cdfs, bins=60, density=True)
plt.xlabel('omegam-PIT')
# Out:
# Text(0.5, 0, 'omegam-PIT')

# %%
plt.hist(sigma8_cdfs, bins=60, density=True)
plt.xlabel('sigma8-PIT')
# Out:
# Text(0.5, 0, 'sigma8-PIT')

# %%
import cloudpickle as pickle

def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f)
        
def load_obj(name):
    with open(name, 'rb') as f:
        return pickle.load(f)

# %%
import jax.numpy as jnp

# %%
history = load_obj('./borg-imnn/newsims/unet/IMNN_history.pkl')

# %%
plt.plot(history['detF'], linestyle='-', label="scaled train")
plt.plot(history['val_detF'], linestyle=':', label="scaled val")

plt.yscale("log")
#plt.xscale("log")

# %%
history["detinvC"][-1]
# Out:
# Array(1.025993, dtype=float32)

# %%
plt.plot(history['detC'], linestyle='-', label="scaled train")
plt.plot(history['val_detC'], linestyle=':', label="scaled val")
plt.plot(history['detinvC'], linestyle='-', label="scaled train")
plt.plot(history['val_detinvC'], linestyle=':', label="scaled val")

plt.yscale("log")

# %%
history = load_obj('./borg-imnn/scaled_net/IMNN_history.pkl')

history_old = load_obj('./borg-imnn/IMNN_history.pkl')

# %%
plt.plot(history['detF'] , linestyle='-', color='b', label="scaled train")
plt.plot(history['val_detF'], linestyle=':', color='lightgreen', label="scaled val")

plt.plot(history_old['detF'], linestyle='-', color='k', label="full train")
plt.plot(history_old['val_detF'], linestyle=':', color='grey', label="full val")

plt.legend(framealpha=0.0)

# %%
history = load_obj('./borg-imnn/sgd/IMNN_history.pkl')

history_old = load_obj('./borg-imnn/IMNN_history.pkl')

# %%
plt.plot(history['detF'] , linestyle='-', color='k', label="SGD train")
plt.plot(history['val_detF'], linestyle=':', color='lightgreen', label="SGD val")

plt.plot(history_old['detF'], linestyle='-', color='k', label="full train")
plt.plot(history_old['val_detF'], linestyle=':', color='grey', label="full val")

plt.legend(framealpha=0.0)
#plt.axhline(1e5)
#plt.xscale('log')

plt.yscale('log')

# %%
imnnF = np.load("./borg-imnn/sgd/IMNN_F.npy")

# %%
np.linalg.det(imnnF)
# Out:
# 72812.414

# %%
plt.plot(history['detinvC'])
plt.plot(history['val_detinvC'])
#plt.xscale('log')

# %%
x = np.load('./borg-imnn/regression/xfull.npy')
pms = np.load('./borg-imnn/regression/thetafull.npy')

def get_S8(omegam, sigma8):
    return sigma8 * np.sqrt(omegam / 0.3)

x_S8 = get_S8(x[:, 0], x[:, 1])
pms_S8 = get_S8(pms[:, 0], pms[:, 1])

# %%
plt.scatter(pms_S8[:], x_S8[:])

# %%
plt.scatter(pms[:, 0], x[:, 0])
