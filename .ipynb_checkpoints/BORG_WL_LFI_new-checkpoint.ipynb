# %%
cd /Users/lucas/repositories/myDelfi
# Out:
# /Users/lucas/repositories/myDelfi

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from plotting import *
from ndes import *
from mdn import *
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
# import data
theta_ = (np.load('./borg-imnn/regression/regression_imnn_theta.npy').astype(np.float32))
summaries_ = np.load('./borg-imnn/regression/regression_imnn_x.npy').astype(np.float32)

max_om = 0.9

mask = theta_[:, 0] < max_om

theta_ = theta_[mask]
summaries_ = summaries_[mask]

weights = np.ones((summaries_.shape[0], 1)).astype(np.float32)


eps = 0.05


# bijector theta -> phi
theta_min = [0.1 - eps, 0.40 - eps]
theta_max = [max_om + eps, 1.6 + eps]
bijector = tfb.Blockwise([tfb.Chain([tfb.Invert(tfb.NormalCDF()), tfb.Scale(np.float32(1./(theta_max[_] - theta_min[_]))), tfb.Shift(-theta_min[_])]) for _ in range(len(theta_min))])

# phi
phi_ = bijector(theta_).numpy()

# %%
theta_[:, 0].min(), theta_[:, 1].min(), theta_[:, 0].max(), theta_[:, 1].max(),
# Out:
# (0.10016517, 0.40023777, 0.89940566, 1.5993524)

# %%
theta_.shape, summaries_.shape, phi_.shape
# Out:
# ((2000, 2), (2000, 2), (2000, 2))

# %%
plt.scatter(theta_[:, 0], (summaries_[:, 0]), s=3)

# %%
plt.scatter(theta_[:, 1], (summaries_[:, 1]), s=3)

# %%
plt.scatter(phi_[:, 0], (summaries_[:, 0]), s=3)
#plt.axvline(0.27, color='k')
plt.show()

# %%
plt.scatter(phi_[:,1], (summaries_[:,1]), s=0.1)
plt.show()

# %%
plt.scatter(theta_[:, 0], phi_[:, 0])

# %%
plt.scatter(theta_[:, 1], phi_[:, 1])

# %%
theta = tf.convert_to_tensor(theta_, dtype=tf.float32)
phi   = tf.convert_to_tensor(phi_, dtype=tf.float32)
weights = tf.convert_to_tensor(weights, dtype=tf.float32)
summaries = tf.convert_to_tensor(summaries_, dtype=tf.float32)

# %%
# Amortized posterior
filename = './borg-imnn/newsims/smallstep/amortized_post'
AmortizedPosterior = MixtureDensityNetwork2(n_components=6, 
                            n_conditionals=2, 
                            n_dimensions=2, 
                            optimizer=tf.keras.optimizers.Adam(lr=1e-3),
                            n_hidden=[100, 100],
                            activation=[tf.tanh, tf.tanh, tf.tanh])
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
#AmortizedPosterior.optimizer = tf.keras.optimizers.Adam(lr=1e-5)
historyAP = AmortizedPosterior.fit(training_conditionals=summaries, training_variables=phi, training_weights=weights, 
                        epochs=1000, batch_size=256, patience=200, save=True, filename=filename)
# Out:
# 100%|██████████| 1000/1000 [00:45<00:00, 22.09it/s, training loss=1.73, validation_loss=1.79]

# %%
# reload best model
AmortizedPosterior = MixtureDensityNetwork2(n_components=6, 
                            n_conditionals=2, 
                            n_dimensions=2, 
                            optimizer=tf.keras.optimizers.Adam(lr=1e-3),
                            n_hidden=[50, 50],
                            activation=[tf.tanh, tf.tanh],
                            restore=True,
                            restore_filename=filename)

# %%
summaries_obs = np.array([0.2662334, 0.7336925]).astype(np.float32) 
# [0.30364028 0.766958  ] [0.3176552, 0.75317466] [0.2464547 0.7625418] [0.2802013, 0.7358817]   [0.2704372  0.79764205]

# %%
# plot over a grid
omegaM = np.linspace(0.11, 0.9, 70)
sigma8 = np.linspace(0.4, 1.6, 110)
OM, S8 = np.meshgrid(omegaM, sigma8)
theta_grid = np.concatenate([OM[...,np.newaxis], S8[...,np.newaxis]], axis=-1)
phi_grid = bijector(theta_grid)


log_prob = tf.squeeze(AmortizedPosterior.log_prob(phi_grid, conditional=summaries_obs*np.ones(theta_grid.shape).astype(np.float32))).numpy()
#log_prob = SamplingDistribution.log_prob(summaries_obs*np.ones(phi_grid.shape).astype(np.float32), conditional=theta_grid).numpy()
log_prob = log_prob - max(log_prob.flatten())

# %%
log_prob
# Out:
# array([[-11.128442 , -10.394818 ,  -9.791271 , ..., -16.96408  ,
#         -18.220081 , -19.757135 ],
#        [-10.13927  ,  -9.414118 ,  -8.818389 , ..., -16.589973 ,
#         -17.868643 , -19.431807 ],
#        [ -9.334416 ,  -8.616729 ,  -8.027936 , ..., -16.314716 ,
#         -17.612688 , -19.19804  ],
#        ...,
#        [-14.111003 , -13.995826 , -13.9495325, ..., -36.903576 ,
#         -38.526608 , -40.479782 ],
#        [-15.172358 , -15.077799 , -15.049774 , ..., -38.33376  ,
#         -39.96483  , -41.92731  ],
#        [-16.459919 , -16.389242 , -16.382391 , ..., -40.04876  ,
#         -41.689148 , -43.662395 ]], dtype=float32)

# %%
plt.contourf(omegaM, sigma8, np.exp(log_prob))
plt.show()

# %%
np.std(theta[:,0])
# Out:
# 0.23223354

# %%
Posterior = AmortizedPosterior.distribution(summaries_obs[np.newaxis, :].astype(np.float32))

posterior_samples = bijector.inverse(Posterior.sample(100000)).numpy()
cut = np.all(~np.isinf(posterior_samples), axis=-1)
posterior_samples = posterior_samples[cut,:]

# %%
plt.hist(posterior_samples[:, 0])
# Out:
# (array([3.8430e+03, 2.0570e+04, 2.8984e+04, 2.3713e+04, 1.4087e+04,
#         6.2100e+03, 2.0280e+03, 4.7600e+02, 8.3000e+01, 6.0000e+00]),
#  array([0.05891932, 0.13618405, 0.21344878, 0.2907135 , 0.36797822,
#         0.44524294, 0.52250767, 0.5997724 , 0.6770371 , 0.75430185,
#         0.8315666 ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
# Posterior = SamplingDistribution.distribution(conditional=summaries_obs[:,np.newaxis].astype(np.float32))

# posterior_samples = (Posterior.sample(10000)).numpy()
# cut = np.all(~np.isinf(posterior_samples), axis=-1)
# posterior_samples = posterior_samples[cut,:]

# %%
triangle_plot([posterior_samples], names={'omegam', 'sigma8'}, labels={'sigma8', 'omegam'}, ranges={'omegam':[0.05, 0.9], 'sigma8':[0.1, 1.6]})
# Out:
# Removed no burn in

# %%
np.save('./borg-imnn/newsims/bignet/posterior_samples', posterior_samples)

# %%
_psts = posterior_samples.copy()
plt.scatter(_psts[:, 0], _psts[:, 1], s=1)

# %%
from chainconsumer import ChainConsumer

_psts = posterior_samples.copy()
#_psts[:, 0] = 0.3*(posterior_samples[:, 0]**2 / posterior_samples[:, 1]**2)

cs = ChainConsumer()
cs.add_chain(_psts, parameters=['omegaM', 'sigma8'], name='DELFI + IMNN') #, color=corner_colors[0])
#cs.add_covariance(θ_target, -Finv_analytic, parameters=params, name="Analytic Fisher", color=corner_colors[2])
cs.configure(linestyles=["-", "-", "-"], linewidths=[1.0, 1.0, 1.0], usetex=False,
        shade=[True, True, False], shade_alpha=[0.7, 0.6, 0.], tick_font_size=8, sigma2d=True)
cs.plotter.plot((7,7))
plt.show()

# %% [markdown]
# # now set up PIT coverage tests
#
# for every pair (theta*, data*) in the training set, for each of the marginals compute P(theta < theta* | data*), and plot the distribution of those cumulative probabilities

# %%
from tqdm import tqdm

# %%
omegam_cdfs = []
sigma8_cdfs = []

for i in tqdm(range(5000)):
  theta_i = theta_[i]
  summary_i = summaries_[i]
  # could add tfp mixture model here for more than one MDN
  # p(theta | x)
  dist = AmortizedPosterior.distribution(summary_i[np.newaxis, :].astype(np.float32))
  
  samps = bijector.inverse(dist.sample(100000)).numpy()
  cut = np.all(~np.isinf(samps), axis=-1)
  samps = samps[cut,:]
  norm = samps.shape[0]


  #for each marginal
  omegam_cdfs.append(np.sum(samps[:, 0] <= theta_i[0]) / norm) 
  sigma8_cdfs.append(np.sum(samps[:, 1] <= theta_i[1]) / norm)

  #plt.hist(samps[:, 1])
  #plt.axvline(theta_i[:, 1])
# Out:
#  60%|█████▉    | 2995/5000 [06:17<04:12,  7.93it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-ee0fefa045ec> in <module>
#       9   dist = AmortizedPosterior.distribution(summary_i[np.newaxis, :].astype(np.float32))
#      10
# ---> 11   samps = bijector.inverse(dist.sample(100000)).numpy()
#      12   cut = np.all(~np.isinf(samps), axis=-1)
#      13   samps = samps[cut,:]
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py in sample(self, sample_shape, seed, name, **kwargs)
#    1232     """
#    1233     with self._name_and_control_scope(name):
# -> 1234       return self._call_sample_n(sample_shape, seed, **kwargs)
#    1235
#    1236   def _call_sample_and_log_prob(self, sample_shape, seed, **kwargs):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py in _call_sample_n(self, sample_shape, seed, **kwargs)
#    1209     sample_shape, n = self._expand_sample_shape_to_vector(
#    1210         sample_shape, 'sample_shape')
# -> 1211     samples = self._sample_n(
#    1212         n, seed=seed() if callable(seed) else seed, **kwargs)
#    1213     samples = tf.nest.map_structure(
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/distributions/mixture.py in _sample_n(self, n, seed)
#     315     for c in range(self.num_components):
#     316       try:
# --> 317         samples.append(self.components[c].sample(n, seed=seeds[c + 1]))
#     318         if seed_stream is not None:
#     319           seed_stream()
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py in sample(self, sample_shape, seed, name, **kwargs)
#    1232     """
#    1233     with self._name_and_control_scope(name):
# -> 1234       return self._call_sample_n(sample_shape, seed, **kwargs)
#    1235
#    1236   def _call_sample_and_log_prob(self, sample_shape, seed, **kwargs):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/distributions/transformed_distribution.py in _call_sample_n(self, sample_shape, seed, **kwargs)
#     325
#     326     # First, generate samples from the base distribution.
# --> 327     x = self._maybe_broadcast_distribution_batch_shape().sample(
#     328         sample_shape=sample_shape, seed=seed, **distribution_kwargs)
#     329     # Apply the bijector's forward transformation. For caching to
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py in sample(self, sample_shape, seed, name, **kwargs)
#    1232     """
#    1233     with self._name_and_control_scope(name):
# -> 1234       return self._call_sample_n(sample_shape, seed, **kwargs)
#    1235
#    1236   def _call_sample_and_log_prob(self, sample_shape, seed, **kwargs):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py in _call_sample_n(self, sample_shape, seed, **kwargs)
#    1209     sample_shape, n = self._expand_sample_shape_to_vector(
#    1210         sample_shape, 'sample_shape')
# -> 1211     samples = self._sample_n(
#    1212         n, seed=seed() if callable(seed) else seed, **kwargs)
#    1213     samples = tf.nest.map_structure(
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/distributions/sample.py in _sample_n(self, n, seed, **kwargs)
#     222   def _sample_n(self, n, seed, **kwargs):
#     223     sample_shape = ps.reshape(self.sample_shape, shape=[-1])
# --> 224     x = self.distribution.sample(ps.concat([[n], sample_shape], axis=0),
#     225                                  seed=seed,
#     226                                  **kwargs)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py in sample(self, sample_shape, seed, name, **kwargs)
#    1232     """
#    1233     with self._name_and_control_scope(name):
# -> 1234       return self._call_sample_n(sample_shape, seed, **kwargs)
#    1235
#    1236   def _call_sample_and_log_prob(self, sample_shape, seed, **kwargs):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py in _call_sample_n(self, sample_shape, seed, **kwargs)
#    1209     sample_shape, n = self._expand_sample_shape_to_vector(
#    1210         sample_shape, 'sample_shape')
# -> 1211     samples = self._sample_n(
#    1212         n, seed=seed() if callable(seed) else seed, **kwargs)
#    1213     samples = tf.nest.map_structure(
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/distributions/normal.py in _sample_n(self, n, seed)
#     175     loc = tf.convert_to_tensor(self.loc)
#     176     scale = tf.convert_to_tensor(self.scale)
# --> 177     shape = ps.concat([[n], self._batch_shape_tensor(loc=loc, scale=scale)],
#     178                       axis=0)
#     179     sampled = samplers.normal(
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py in _batch_shape_tensor(self, **parameter_kwargs)
#    1011     """
#    1012     try:
# -> 1013       return batch_shape_lib.inferred_batch_shape_tensor(
#    1014           self, **parameter_kwargs)
#    1015     except NotImplementedError:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/batch_shape_lib.py in inferred_batch_shape_tensor(batch_object, bijector_x_event_ndims, **parameter_kwargs)
#     108     batch_shape_tensor: `Tensor` broadcast batch shape of all parameters.
#     109   """
# --> 110   batch_shapes = map_fn_over_parameters_with_event_ndims(
#     111       batch_object,
#     112       get_batch_shape_tensor_part,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/batch_shape_lib.py in map_fn_over_parameters_with_event_ndims(batch_object, fn, bijector_x_event_ndims, require_static, **parameter_kwargs)
#     359         param = tensor_util.convert_nonref_to_tensor(param, name=param_name)
#     360
# --> 361     results[param_name] = nest.map_structure_up_to(
#     362         param, fn, param, param_event_ndims)
#     363   return results
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure_up_to(shallow_tree, func, *inputs, **kwargs)
#    1374     `shallow_tree`.
#    1375   """
# -> 1376   return map_structure_with_tuple_paths_up_to(
#    1377       shallow_tree,
#    1378       lambda _, *values: func(*values),  # Discards the path arg.
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure_with_tuple_paths_up_to(shallow_tree, func, *inputs, **kwargs)
#    1472   flat_path_gen = (
#    1473       path for path, _ in _yield_flat_up_to(shallow_tree, inputs[0], is_seq))
# -> 1474   results = [
#    1475       func(*args, **kwargs) for args in zip(flat_path_gen, *flat_value_gen)
#    1476   ]
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#    1473       path for path, _ in _yield_flat_up_to(shallow_tree, inputs[0], is_seq))
#    1474   results = [
# -> 1475       func(*args, **kwargs) for args in zip(flat_path_gen, *flat_value_gen)
#    1476   ]
#    1477   return pack_sequence_as(structure=shallow_tree, flat_sequence=results,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <lambda>(_, *values)
#    1376   return map_structure_with_tuple_paths_up_to(
#    1377       shallow_tree,
# -> 1378       lambda _, *values: func(*values),  # Discards the path arg.
#    1379       *inputs,
#    1380       **kwargs)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/batch_shape_lib.py in get_batch_shape_tensor_part(x, event_ndims)
#     133       base_shape = functools.reduce(ps.broadcast_shape,
#     134                                     tf.nest.flatten(base_shape))
# --> 135   elif hasattr(x, 'shape') and tensorshape_util.is_fully_defined(x.shape):
#     136     base_shape = x.shape
#     137   else:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow_probability/python/internal/tensorshape_util.py in is_fully_defined(x)
#     223     is_fully_defined: `bool` indicating that the shape is fully known.
#     224   """
# --> 225   return tf.TensorShape(x).is_fully_defined()
#     226
#     227
#
# /usr/local/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/tensor_shape.py in is_fully_defined(self)
#    1204     """Returns True iff `self` is fully defined in every dimension."""
#    1205     return (self._dims is not None and
# -> 1206             all(dim.value is not None for dim in self._dims))
#    1207
#    1208   def assert_is_fully_defined(self):
#
# KeyboardInterrupt:

# %%
plt.hist(omegam_cdfs, bins=60, density=True)
plt.xlabel('omegam-PIT')
# Out:
# Text(0.5, 0, 'omegam-PIT')

# %%
plt.hist(sigma8_cdfs, bins=60, density=True)
plt.xlabel('sigma8-PIT')
# Out:
# Text(0.5, 0, 'sigma8-PIT')

# %%
import cloudpickle as pickle

def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f)
        
def load_obj(name):
    with open(name, 'rb') as f:
        return pickle.load(f)

# %%
import jax.numpy as jnp

# %%
history = load_obj('./borg-imnn/scaled_net/IMNN_history.pkl')

history_old = load_obj('./borg-imnn/IMNN_history.pkl')

# %%
plt.plot(history['detF'] , linestyle='-', color='b', label="scaled train")
plt.plot(history['val_detF'], linestyle=':', color='lightgreen', label="scaled val")

plt.plot(history_old['detF'], linestyle='-', color='k', label="full train")
plt.plot(history_old['val_detF'], linestyle=':', color='grey', label="full val")

plt.legend(framealpha=0.0)

# %%
history = load_obj('./borg-imnn/newsims/IMNN_history.pkl')

#history_old = load_obj('./borg-imnn/IMNN_history.pkl')

# %%
plt.plot(history['detF'] , linestyle='-', color='k', label="train")
plt.plot(history['val_detF'], linestyle=':', color='lightgreen', label="val")

#plt.plot(history_old['detF'], linestyle='-', color='k', label="full train")
#plt.plot(history_old['val_detF'], linestyle=':', color='grey', label="full val")

plt.legend(framealpha=0.0)
#plt.axhline(1e5)
#plt.xscale('log')

plt.yscale('log')

# %%
imnnF = np.load("./borg-imnn/sgd/IMNN_F.npy")

# %%
np.linalg.det(imnnF)
# Out:
# 72812.414

# %%
plt.plot(history['detinvC'])
plt.plot(history['val_detinvC'])
#plt.xscale('log')
